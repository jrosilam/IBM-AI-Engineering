# %% [markdown]
# <a href="http://cocl.us/pytorch_link_top">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/Pytochtop.png" width="750" alt="IBM Product " />
# </a>

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/cc-logo-square.png" width="200" alt="cognitiveclass.ai logo" />

# %% [markdown]
# # Pre-trained-Models with PyTorch

# %% [markdown]
# In this lab, we will use pre-trained models to classify between the negative and positive samples; you will be provided with the dataset object. The particular pre-trained model will be resnet18; you will have three questions:
#
# + change the output layer
#
# + train the model
#
# + identify  several  misclassified samples
#
# You will take several screenshots of your work and share your notebook.

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# 1. Download Data
#
# 2. Imports and Auxiliary Functions
#
# 3. Dataset Class
#
# 4. Question 1
#
# 5. Question 2
#
# 6. Question 3
#
# **Estimated Time Needed: <strong>120 min</strong>**

# %% [markdown]
# ## Mount your Google Drive files by running the following code snippet

# %% [raw]
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## Change current working directory

# %% [raw]
# %cd "/content/drive/My Drive/Colab Notebooks/data"

# %% [raw]
# # Verify the current working directory
# %pwd

# %% [raw]
# # List the content in given directory path
# !ls "/content/drive/My Drive/Colab Notebooks/data"

# %% [markdown]
# ## Download Data

# %% [markdown]
# Download the dataset and unzip the files in your data directory, unlike the other labs, all the data will be deleted after you close  the lab, this may take some time:

# %% [raw]
# #!wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# #!unzip -q Positive_tensors.zip

# %% [raw]
# #! wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
#
# #!unzip -q Negative_tensors.zip

# %% [markdown]
# We will install torchvision:

# %% [raw]
# #!pip install torchvision

# %%
import os

current_directory_path = os.getcwd()
current_directory_path

# Path in local machine
data_path = "./resources/data/"
model_path = "./resources/data/model/"

# %% [markdown]
# Verify the number of files in input corpus

# %%
output_dir = data_path + "/Positive_tensors"
if os.path.exists(output_dir):
    print("Number of files in directory '{}' : {}".format(output_dir, len([name for name in os.listdir(output_dir)])))

output_dir = data_path + "/Negative_tensors"
if os.path.exists(output_dir):
    print("Number of files in directory '{}' : {}".format(output_dir, len([name for name in os.listdir(output_dir)])))
# Out:
# Number of files in directory './resources/data//Positive_tensors' : 20000
# Number of files in directory './resources/data//Negative_tensors' : 20000

# %% [markdown]
# ## Imports and Auxiliary Functions

# %% [markdown]
# The following are the libraries we are going to use for this lab. The <code>torch.manual_seed()</code> is for forcing the random function to give the same number every time we try to recompile it.

# %%
# These are the libraries will be used for this lab.
import torchvision.models as models
from PIL import Image
import pandas
from torchvision import transforms
import torch.nn as nn
import time
import torch 
import matplotlib.pylab as plt
import numpy as np
from torch.utils.data import Dataset, DataLoader
import h5py
import os
import glob
torch.manual_seed(0)

# %%
from matplotlib.pyplot import imshow
import matplotlib.pylab as plt
from PIL import Image
import pandas as pd
import os

# %%
print("PyTorch version : ", torch.__version__)
# Out:
# PyTorch version :  1.3.0

# %% [markdown]
# ## Change Default Device - GPU / CPU

# %%
def get_default_device():
  """ Pick GPU if available else CPU. In Google Colab, we should change parameter "Hardware Accelerator" in menu item "Edit > Notebook Settings"
  """
  if torch.cuda.is_available():  
    print("Using GPU")
    return torch.device("cuda")  

  print("Using CPU")
  return torch.device("cpu")
# end def

use_cuda = True  # Use GPU
device = torch.device("cpu")
if use_cuda:
  device = get_default_device()
# Out:
# Using CPU

# %% [markdown]
# ## Dataset Class

# %% [markdown]
#  This dataset class is essentially the same dataset you build in the previous section, but to speed things up, we are going to use tensors instead of jpeg images. Therefor for each iteration, you will skip the reshape step, conversion step to tensors and normalization step.

# %%
# Create your own dataset object

class Dataset(Dataset):

    # Constructor
    def __init__(self, transform=None, train=True):
        directory = data_path 
        positive = "Positive_tensors"
        negative = "Negative_tensors"

        positive_file_path = os.path.join(directory, positive)
        negative_file_path = os.path.join(directory, negative)
        positive_files = [os.path.join(positive_file_path, file) for file in os.listdir(positive_file_path) if file.endswith(".pt")]
        negative_files = [os.path.join(negative_file_path, file) for file in os.listdir(negative_file_path) if file.endswith(".pt")]
        
        number_of_samples = len(positive_files)+len(negative_files)
        
        self.all_files = [None]*number_of_samples
        self.all_files[::2] = positive_files
        self.all_files[1::2] = negative_files 
        
        # The transform is goint to be used on image
        self.transform = transform
        
        #torch.LongTensor
        self.Y = torch.zeros([number_of_samples]).type(torch.LongTensor)
        self.Y[::2] = 1
        self.Y[1::2] = 0
        
        NUM_OF_ITEMS_FOR_SPLITTING = 30000
        if train:
            self.all_files = self.all_files[:NUM_OF_ITEMS_FOR_SPLITTING]
            self.Y = self.Y[:NUM_OF_ITEMS_FOR_SPLITTING]
            self.len = len(self.all_files)
        else:
            self.all_files = self.all_files[NUM_OF_ITEMS_FOR_SPLITTING:]
            self.Y = self.Y[NUM_OF_ITEMS_FOR_SPLITTING:]
            self.len = len(self.all_files)     
       
    # Get the length
    def __len__(self):
        return self.len
    
    # Getter
    def __getitem__(self, idx):               
        image = torch.load(self.all_files[idx])
        y = self.Y[idx]
                  
        # If there is any transform method, apply it onto the image
        if self.transform:
            image = self.transform(image)
        return image, y
    
print("done")
# Out:
# done

# %% [markdown]
# We create two dataset objects, one for the training data and one for the validation data.

# %%
train_dataset = Dataset(train=True)
validation_dataset = Dataset(train=False)
print("done")
# Out:
# done

# %% [markdown]
# ## Question 1

# %% [markdown]
# <b>Prepare a pre-trained resnet18 model :</b>

# %% [markdown]
# <b>Step 1</b>: Load the pre-trained model <code>resnet18</code> Set the parameter <code>pretrained</code> to true:

# %%
# Step 1: Load the pre-trained model resnet18
import torchvision.models as models

model = models.resnet18(pretrained=True)
# Out:
# c:\Users\jesus\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\jesus\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model = model.to(device)
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# <b>Step 2</b>: Set the attribute <code>requires_grad</code> to <code>False</code>. As a result, the parameters will not be affected by training.

# %%
# Step 2: Set the parameter cannot be trained for the pre-trained model
for param in model.parameters():
    param.requires_grad = False

# %% [markdown]
# <code>resnet18</code> is used to classify 1000 different objects; as a result, the last layer has 1000 outputs.  The 512 inputs come from the fact that the previously hidden layer has 512 outputs.

# %% [markdown]
# <b>Step 3</b>: Replace the output layer <code>model.fc</code> of the neural network with a <code>nn.Linear</code> object, to classify 2 different classes. For the parameters <code>in_features </code> remember the last hidden layer has 512 neurons.

# %%
# Dimension of last layer
d_hidden = 512
d_out = 2

model.fc = nn.Linear(d_hidden, d_out)  # replace the output layer

# %% [markdown]
# Print out the model in order to show whether you get the correct answer.<br> <b>(Your peer reviewer is going to mark based on what you print here.)</b>

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# ## Question 2: Train the Model

# %% [markdown]
# In this question you will train your, model:

# %% [markdown]
# <b>Step 1</b>: Create a cross entropy criterion function

# %%
# Step 1: Create the loss function
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# <b>Step 2</b>: Create a training loader and validation loader object, the batch size should have 100 samples each.

# %%
batch_size = 100

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size)
validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=batch_size)

# %% [markdown]
# <b>Step 3</b>: Use the following optimizer to minimize the loss

# %%
# Verify the parameters whose requires_grad are True
for param in model.parameters():
  if param.requires_grad:
    print(param)
# Out:
# Parameter containing:
# tensor([[ 0.0342, -0.0255,  0.0249,  ...,  0.0130, -0.0365, -0.0426],
#         [ 0.0411, -0.0204,  0.0384,  ...,  0.0156, -0.0340,  0.0069]],
#        requires_grad=True)
# Parameter containing:
# tensor([0.0074, 0.0091], requires_grad=True)

# %%
optimizer = torch.optim.Adam([parameters for parameters in model.parameters() if parameters.requires_grad],
                             lr=0.001)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# **Complete the following code to calculate  the accuracy on the validation data for one epoch; this should take about 45 minutes. Make sure you calculate the accuracy on the validation data.**

# %%
n_epochs = 1
loss_list = []
accuracy_list = []
accuracy = 0
correct = 0
N_test = len(validation_dataset)
N_train = len(train_dataset)
start_time = time.time()
#n_epochs

print("Number of items in training set : ", N_train)
print("Number of items in testing set : ", N_test)

running_loss = 0
start_time = time.time()
for epoch in range(n_epochs):
    for i, (x, y) in enumerate(train_loader):        
        print('-' * 30)
        print('Iteration (train phase) {}/{}'.format(i+1, int(N_train/batch_size)))
        i_start_time = time.time()
        x = x.to(device)
        y = y.to(device)
        # set model to train 
        model.train() 
        # clear gradient 
        optimizer.zero_grad()
        # make a prediction 
        z = model(x)
        # calculate loss 
        loss = criterion(z, y) 
        # calculate gradients of parameters 
        loss.backward()
        # update parameters 
        optimizer.step()
        loss_list.append(loss.data)
        print("Finished in {} (s)".format(time.time()-i_start_time))
    # end for
        
    correct=0
    for i, (x_test, y_test) in enumerate(validation_loader):
        print('-' * 30)
        print('Iteration (validation phase) {}/{}'.format(i+1, int(N_test/batch_size)))
        i_start_time = time.time()
        
        x_test = x_test.to(device)
        y_test = y_test.to(device)
        
        # set model to eval 
        model.eval()
       
        # make a prediction 
        z = model(x_test)
        
        # find max 
        _, yhat = torch.max(z.data, 1)
       
       
        #Calculate misclassified  samples in mini-batch 
        #hint +=(yhat==y_test).sum().item()
        correct += (yhat==y_test).sum().item()  
        
        print("Finished in {} (s)".format(time.time()-i_start_time))
    
    accuracy=correct/N_test
    print("Epoch %d - accuracy: %.3f" % (epoch+1, accuracy))
    
    accuracy_list.append(accuracy)
    print("-" * 72)
    
    # Save model
    model_file_path = model_path + "resnet18_trained_model_epoch_{}.pth".format(epoch+1)
    torch.save(model.state_dict(), model_file_path)
    
    # Duration for epoch
    print("Finished epoch {} in {} (s).".format(epoch+1, time.time()-start_time))
# Out:
# Number of items in training set :  30000
# Number of items in testing set :  10000
# ------------------------------
# Iteration (train phase) 1/300
# Finished in 1.3797895908355713 (s)
# ------------------------------
# Iteration (train phase) 2/300
# Finished in 1.2452337741851807 (s)
# ------------------------------
# Iteration (train phase) 3/300
# Finished in 1.2358982563018799 (s)
# ------------------------------
# Iteration (train phase) 4/300
# Finished in 1.2536027431488037 (s)
# ------------------------------
# Iteration (train phase) 5/300
# Finished in 1.2088963985443115 (s)
# ------------------------------
# Iteration (train phase) 6/300
# Finished in 1.2219834327697754 (s)
# ------------------------------
# Iteration (train phase) 7/300
# Finished in 1.2376065254211426 (s)
# ------------------------------
# Iteration (train phase) 8/300
# Finished in 1.2282421588897705 (s)
# ------------------------------
# Iteration (train phase) 9/300
# Finished in 1.2168073654174805 (s)
# ------------------------------
# Iteration (train phase) 10/300
# Finished in 1.2427051067352295 (s)
# ------------------------------
# Iteration (train phase) 11/300
# Finished in 1.1951847076416016 (s)
# ------------------------------
# Iteration (train phase) 12/300
# Finished in 1.241689682006836 (s)
# ------------------------------
# Iteration (train phase) 13/300
# Finished in 1.211883783340454 (s)
# ------------------------------
# Iteration (train phase) 14/300
# Finished in 1.2325913906097412 (s)
# ------------------------------
# Iteration (train phase) 15/300
# Finished in 1.1791858673095703 (s)
# ------------------------------
# Iteration (train phase) 16/300
# Finished in 1.2138001918792725 (s)
# ------------------------------
# Iteration (train phase) 17/300
# Finished in 1.2563414573669434 (s)
# ------------------------------
# Iteration (train phase) 18/300
# Finished in 1.2193279266357422 (s)
# ------------------------------
# Iteration (train phase) 19/300
# Finished in 1.166917085647583 (s)
# ------------------------------
# Iteration (train phase) 20/300
# Finished in 1.93768310546875 (s)
# ------------------------------
# Iteration (train phase) 21/300
# Finished in 1.765106201171875 (s)
# ------------------------------
# Iteration (train phase) 22/300
# Finished in 2.11564564704895 (s)
# ------------------------------
# Iteration (train phase) 23/300
# Finished in 2.004558563232422 (s)
# ------------------------------
# Iteration (train phase) 24/300
# Finished in 2.022123336791992 (s)
# ------------------------------
# Iteration (train phase) 25/300
# Finished in 2.100893497467041 (s)
# ------------------------------
# Iteration (train phase) 26/300
# Finished in 2.0796170234680176 (s)
# ------------------------------
# Iteration (train phase) 27/300
# Finished in 2.0521416664123535 (s)
# ------------------------------
# Iteration (train phase) 28/300
# Finished in 2.0746591091156006 (s)
# ------------------------------
# Iteration (train phase) 29/300
# Finished in 2.091325521469116 (s)
# ------------------------------
# Iteration (train phase) 30/300
# Finished in 2.2138864994049072 (s)
# ------------------------------
# Iteration (train phase) 31/300
# Finished in 2.146401882171631 (s)
# ------------------------------
# Iteration (train phase) 32/300
# Finished in 2.0835154056549072 (s)
# ------------------------------
# Iteration (train phase) 33/300
# Finished in 2.1436431407928467 (s)
# ------------------------------
# Iteration (train phase) 34/300
# Finished in 2.3459231853485107 (s)
# ------------------------------
# Iteration (train phase) 35/300
# Finished in 2.365872621536255 (s)
# ------------------------------
# Iteration (train phase) 36/300
# Finished in 1.5035912990570068 (s)
# ------------------------------
# Iteration (train phase) 37/300
# Finished in 1.2737233638763428 (s)
# ------------------------------
# Iteration (train phase) 38/300
# Finished in 1.3052451610565186 (s)
# ------------------------------
# Iteration (train phase) 39/300
# Finished in 2.454301595687866 (s)
# ------------------------------
# Iteration (train phase) 40/300
# Finished in 2.0528488159179688 (s)
# ------------------------------
# Iteration (train phase) 41/300
# Finished in 2.4499614238739014 (s)
# ------------------------------
# Iteration (train phase) 42/300
# Finished in 2.4701359272003174 (s)
# ------------------------------
# Iteration (train phase) 43/300
# Finished in 2.521758556365967 (s)
# ------------------------------
# Iteration (train phase) 44/300
# Finished in 2.492737054824829 (s)
# ------------------------------
# Iteration (train phase) 45/300
# Finished in 2.4227566719055176 (s)
# ------------------------------
# Iteration (train phase) 46/300
# Finished in 2.4219536781311035 (s)
# ------------------------------
# Iteration (train phase) 47/300
# Finished in 2.6262710094451904 (s)
# ------------------------------
# Iteration (train phase) 48/300
# Finished in 2.4268767833709717 (s)
# ------------------------------
# Iteration (train phase) 49/300
# Finished in 2.447680950164795 (s)
# ------------------------------
# Iteration (train phase) 50/300
# Finished in 2.340120553970337 (s)
# ------------------------------
# Iteration (train phase) 51/300
# Finished in 2.376396417617798 (s)
# ------------------------------
# Iteration (train phase) 52/300
# Finished in 2.3742241859436035 (s)
# ------------------------------
# Iteration (train phase) 53/300
# Finished in 2.47633695602417 (s)
# ------------------------------
# Iteration (train phase) 54/300
# Finished in 2.5219645500183105 (s)
# ------------------------------
# Iteration (train phase) 55/300
# Finished in 2.6191465854644775 (s)
# ------------------------------
# Iteration (train phase) 56/300
# Finished in 2.656087875366211 (s)
# ------------------------------
# Iteration (train phase) 57/300
# Finished in 3.4643936157226562 (s)
# ------------------------------
# Iteration (train phase) 58/300
# Finished in 3.416639566421509 (s)
# ------------------------------
# Iteration (train phase) 59/300
# Finished in 3.7436416149139404 (s)
# ------------------------------
# Iteration (train phase) 60/300
# Finished in 3.811100959777832 (s)
# ------------------------------
# Iteration (train phase) 61/300
# Finished in 2.555753469467163 (s)
# ------------------------------
# Iteration (train phase) 62/300
# Finished in 2.3827061653137207 (s)
# ------------------------------
# Iteration (train phase) 63/300
# Finished in 2.4227614402770996 (s)
# ------------------------------
# Iteration (train phase) 64/300
# Finished in 3.1141157150268555 (s)
# ------------------------------
# Iteration (train phase) 65/300
# Finished in 2.5658998489379883 (s)
# ------------------------------
# Iteration (train phase) 66/300
# Finished in 2.3852155208587646 (s)
# ------------------------------
# Iteration (train phase) 67/300
# Finished in 2.419018268585205 (s)
# ------------------------------
# Iteration (train phase) 68/300
# Finished in 2.7882649898529053 (s)
# ------------------------------
# Iteration (train phase) 69/300
# Finished in 3.063119888305664 (s)
# ------------------------------
# Iteration (train phase) 70/300
# Finished in 3.289320707321167 (s)
# ------------------------------
# Iteration (train phase) 71/300
# Finished in 2.3341877460479736 (s)
# ------------------------------
# Iteration (train phase) 72/300
# Finished in 2.3084909915924072 (s)
# ------------------------------
# Iteration (train phase) 73/300
# Finished in 2.1921041011810303 (s)
# ------------------------------
# Iteration (train phase) 74/300
# Finished in 2.4612584114074707 (s)
# ------------------------------
# Iteration (train phase) 75/300
# Finished in 2.380666732788086 (s)
# ------------------------------
# Iteration (train phase) 76/300
# Finished in 2.352490186691284 (s)
# ------------------------------
# Iteration (train phase) 77/300
# Finished in 2.3803319931030273 (s)
# ------------------------------
# Iteration (train phase) 78/300
# Finished in 2.210291624069214 (s)
# ------------------------------
# Iteration (train phase) 79/300
# Finished in 2.33978009223938 (s)
# ------------------------------
# Iteration (train phase) 80/300
# Finished in 2.5486645698547363 (s)
# ------------------------------
# Iteration (train phase) 81/300
# Finished in 2.6805503368377686 (s)
# ------------------------------
# Iteration (train phase) 82/300
# Finished in 2.6756653785705566 (s)
# ------------------------------
# Iteration (train phase) 83/300
# Finished in 3.017101287841797 (s)
# ------------------------------
# Iteration (train phase) 84/300
# Finished in 3.1504647731781006 (s)
# ------------------------------
# Iteration (train phase) 85/300
# Finished in 3.153470754623413 (s)
# ------------------------------
# Iteration (train phase) 86/300
# Finished in 3.2285170555114746 (s)
# ------------------------------
# Iteration (train phase) 87/300
# Finished in 2.9043233394622803 (s)
# ------------------------------
# Iteration (train phase) 88/300
# Finished in 2.4775075912475586 (s)
# ------------------------------
# Iteration (train phase) 89/300
# Finished in 3.440967082977295 (s)
# ------------------------------
# Iteration (train phase) 90/300
# Finished in 2.735163927078247 (s)
# ------------------------------
# Iteration (train phase) 91/300
# Finished in 2.9708948135375977 (s)
# ------------------------------
# Iteration (train phase) 92/300
# Finished in 2.7971599102020264 (s)
# ------------------------------
# Iteration (train phase) 93/300
# Finished in 2.9927279949188232 (s)
# ------------------------------
# Iteration (train phase) 94/300
# Finished in 2.5587549209594727 (s)
# ------------------------------
# Iteration (train phase) 95/300
# Finished in 2.9691243171691895 (s)
# ------------------------------
# Iteration (train phase) 96/300
# Finished in 2.669318199157715 (s)
# ------------------------------
# Iteration (train phase) 97/300
# Finished in 3.0192463397979736 (s)
# ------------------------------
# Iteration (train phase) 98/300
# Finished in 3.3136534690856934 (s)
# ------------------------------
# Iteration (train phase) 99/300
# Finished in 2.7026045322418213 (s)
# ------------------------------
# Iteration (train phase) 100/300
# Finished in 2.514084815979004 (s)
# ------------------------------
# Iteration (train phase) 101/300
# Finished in 2.471625804901123 (s)
# ------------------------------
# Iteration (train phase) 102/300
# Finished in 2.318845748901367 (s)
# ------------------------------
# Iteration (train phase) 103/300
# Finished in 2.3609793186187744 (s)
# ------------------------------
# Iteration (train phase) 104/300
# Finished in 2.4983322620391846 (s)
# ------------------------------
# Iteration (train phase) 105/300
# Finished in 2.3629846572875977 (s)
# ------------------------------
# Iteration (train phase) 106/300
# Finished in 2.2628321647644043 (s)
# ------------------------------
# Iteration (train phase) 107/300
# Finished in 2.3269741535186768 (s)
# ------------------------------
# Iteration (train phase) 108/300
# Finished in 2.3695669174194336 (s)
# ------------------------------
# Iteration (train phase) 109/300
# Finished in 2.2478156089782715 (s)
# ------------------------------
# Iteration (train phase) 110/300
# Finished in 2.3768811225891113 (s)
# ------------------------------
# Iteration (train phase) 111/300
# Finished in 2.3376667499542236 (s)
# ------------------------------
# Iteration (train phase) 112/300
# Finished in 2.336416482925415 (s)
# ------------------------------
# Iteration (train phase) 113/300
# Finished in 2.3547143936157227 (s)
# ------------------------------
# Iteration (train phase) 114/300
# Finished in 2.306208372116089 (s)
# ------------------------------
# Iteration (train phase) 115/300
# Finished in 2.4261460304260254 (s)
# ------------------------------
# Iteration (train phase) 116/300
# Finished in 2.344270706176758 (s)
# ------------------------------
# Iteration (train phase) 117/300
# Finished in 2.4269721508026123 (s)
# ------------------------------
# Iteration (train phase) 118/300
# Finished in 2.374795436859131 (s)
# ------------------------------
# Iteration (train phase) 119/300
# Finished in 2.410963773727417 (s)
# ------------------------------
# Iteration (train phase) 120/300
# Finished in 2.3327701091766357 (s)
# ------------------------------
# Iteration (train phase) 121/300
# Finished in 2.3179500102996826 (s)
# ------------------------------
# Iteration (train phase) 122/300
# Finished in 2.3421599864959717 (s)
# ------------------------------
# Iteration (train phase) 123/300
# Finished in 2.2774462699890137 (s)
# ------------------------------
# Iteration (train phase) 124/300
# Finished in 2.3979504108428955 (s)
# ------------------------------
# Iteration (train phase) 125/300
# Finished in 2.419243812561035 (s)
# ------------------------------
# Iteration (train phase) 126/300
# Finished in 2.3965561389923096 (s)
# ------------------------------
# Iteration (train phase) 127/300
# Finished in 2.2771501541137695 (s)
# ------------------------------
# Iteration (train phase) 128/300
# Finished in 2.4193363189697266 (s)
# ------------------------------
# Iteration (train phase) 129/300
# Finished in 2.4234254360198975 (s)
# ------------------------------
# Iteration (train phase) 130/300
# Finished in 2.3718976974487305 (s)
# ------------------------------
# Iteration (train phase) 131/300
# Finished in 2.3524961471557617 (s)
# ------------------------------
# Iteration (train phase) 132/300
# Finished in 2.327167510986328 (s)
# ------------------------------
# Iteration (train phase) 133/300
# Finished in 3.1502366065979004 (s)
# ------------------------------
# Iteration (train phase) 134/300
# Finished in 2.8649163246154785 (s)
# ------------------------------
# Iteration (train phase) 135/300
# Finished in 2.34387469291687 (s)
# ------------------------------
# Iteration (train phase) 136/300
# Finished in 2.369490385055542 (s)
# ------------------------------
# Iteration (train phase) 137/300
# Finished in 2.3270578384399414 (s)
# ------------------------------
# Iteration (train phase) 138/300
# Finished in 2.2391200065612793 (s)
# ------------------------------
# Iteration (train phase) 139/300
# Finished in 2.410831928253174 (s)
# ------------------------------
# Iteration (train phase) 140/300
# Finished in 2.345233201980591 (s)
# ------------------------------
# Iteration (train phase) 141/300
# Finished in 2.3608412742614746 (s)
# ------------------------------
# Iteration (train phase) 142/300
# Finished in 2.3764021396636963 (s)
# ------------------------------
# Iteration (train phase) 143/300
# Finished in 3.8076648712158203 (s)
# ------------------------------
# Iteration (train phase) 144/300
# Finished in 1.7996551990509033 (s)
# ------------------------------
# Iteration (train phase) 145/300
# Finished in 1.7254607677459717 (s)
# ------------------------------
# Iteration (train phase) 146/300
# Finished in 2.7644708156585693 (s)
# ------------------------------
# Iteration (train phase) 147/300
# Finished in 2.44348406791687 (s)
# ------------------------------
# Iteration (train phase) 148/300
# Finished in 2.713690757751465 (s)
# ------------------------------
# Iteration (train phase) 149/300
# Finished in 2.519868850708008 (s)
# ------------------------------
# Iteration (train phase) 150/300
# Finished in 2.9260377883911133 (s)
# ------------------------------
# Iteration (train phase) 151/300
# Finished in 2.7503950595855713 (s)
# ------------------------------
# Iteration (train phase) 152/300
# Finished in 2.4673357009887695 (s)
# ------------------------------
# Iteration (train phase) 153/300
# Finished in 2.465571403503418 (s)
# ------------------------------
# Iteration (train phase) 154/300
# Finished in 2.6346535682678223 (s)
# ------------------------------
# Iteration (train phase) 155/300
# Finished in 2.5487730503082275 (s)
# ------------------------------
# Iteration (train phase) 156/300
# Finished in 2.4772748947143555 (s)
# ------------------------------
# Iteration (train phase) 157/300
# Finished in 2.6315648555755615 (s)
# ------------------------------
# Iteration (train phase) 158/300
# Finished in 2.5395777225494385 (s)
# ------------------------------
# Iteration (train phase) 159/300
# Finished in 2.537917137145996 (s)
# ------------------------------
# Iteration (train phase) 160/300
# Finished in 2.6697542667388916 (s)
# ------------------------------
# Iteration (train phase) 161/300
# Finished in 2.27766489982605 (s)
# ------------------------------
# Iteration (train phase) 162/300
# Finished in 2.4075512886047363 (s)
# ------------------------------
# Iteration (train phase) 163/300
# Finished in 2.3148648738861084 (s)
# ------------------------------
# Iteration (train phase) 164/300
# Finished in 2.5458972454071045 (s)
# ------------------------------
# Iteration (train phase) 165/300
# Finished in 2.531578540802002 (s)
# ------------------------------
# Iteration (train phase) 166/300
# Finished in 2.5693066120147705 (s)
# ------------------------------
# Iteration (train phase) 167/300
# Finished in 2.798218250274658 (s)
# ------------------------------
# Iteration (train phase) 168/300
# Finished in 2.924435615539551 (s)
# ------------------------------
# Iteration (train phase) 169/300
# Finished in 3.1338980197906494 (s)
# ------------------------------
# Iteration (train phase) 170/300
# Finished in 3.1998238563537598 (s)
# ------------------------------
# Iteration (train phase) 171/300
# Finished in 1.6988589763641357 (s)
# ------------------------------
# Iteration (train phase) 172/300
# Finished in 1.7121644020080566 (s)
# ------------------------------
# Iteration (train phase) 173/300
# Finished in 1.7014474868774414 (s)
# ------------------------------
# Iteration (train phase) 174/300
# Finished in 2.687429189682007 (s)
# ------------------------------
# Iteration (train phase) 175/300
# Finished in 2.6147356033325195 (s)
# ------------------------------
# Iteration (train phase) 176/300
# Finished in 2.464181423187256 (s)
# ------------------------------
# Iteration (train phase) 177/300
# Finished in 2.704840660095215 (s)
# ------------------------------
# Iteration (train phase) 178/300
# Finished in 2.4405531883239746 (s)
# ------------------------------
# Iteration (train phase) 179/300
# Finished in 2.5280518531799316 (s)
# ------------------------------
# Iteration (train phase) 180/300
# Finished in 2.539778470993042 (s)
# ------------------------------
# Iteration (train phase) 181/300
# Finished in 3.0790770053863525 (s)
# ------------------------------
# Iteration (train phase) 182/300
# Finished in 2.940823793411255 (s)
# ------------------------------
# Iteration (train phase) 183/300
# Finished in 2.537571668624878 (s)
# ------------------------------
# Iteration (train phase) 184/300
# Finished in 2.4696428775787354 (s)
# ------------------------------
# Iteration (train phase) 185/300
# Finished in 2.623065233230591 (s)
# ------------------------------
# Iteration (train phase) 186/300
# Finished in 2.526759147644043 (s)
# ------------------------------
# Iteration (train phase) 187/300
# Finished in 2.479215621948242 (s)
# ------------------------------
# Iteration (train phase) 188/300
# Finished in 2.5731985569000244 (s)
# ------------------------------
# Iteration (train phase) 189/300
# Finished in 2.561626434326172 (s)
# ------------------------------
# Iteration (train phase) 190/300
# Finished in 2.6014294624328613 (s)
# ------------------------------
# Iteration (train phase) 191/300
# Finished in 2.471046209335327 (s)
# ------------------------------
# Iteration (train phase) 192/300
# Finished in 2.3416335582733154 (s)
# ------------------------------
# Iteration (train phase) 193/300
# Finished in 2.542541742324829 (s)
# ------------------------------
# Iteration (train phase) 194/300
# Finished in 2.594142198562622 (s)
# ------------------------------
# Iteration (train phase) 195/300
# Finished in 2.4207403659820557 (s)
# ------------------------------
# Iteration (train phase) 196/300
# Finished in 2.591939926147461 (s)
# ------------------------------
# Iteration (train phase) 197/300
# Finished in 2.6920244693756104 (s)
# ------------------------------
# Iteration (train phase) 198/300
# Finished in 2.5044455528259277 (s)
# ------------------------------
# Iteration (train phase) 199/300
# Finished in 2.4856154918670654 (s)
# ------------------------------
# Iteration (train phase) 200/300
# Finished in 2.546872854232788 (s)
# ------------------------------
# Iteration (train phase) 201/300
# Finished in 2.4261815547943115 (s)
# ------------------------------
# Iteration (train phase) 202/300
# Finished in 2.506896495819092 (s)
# ------------------------------
# Iteration (train phase) 203/300
# Finished in 2.549438714981079 (s)
# ------------------------------
# Iteration (train phase) 204/300
# Finished in 2.5060386657714844 (s)
# ------------------------------
# Iteration (train phase) 205/300
# Finished in 2.5043511390686035 (s)
# ------------------------------
# Iteration (train phase) 206/300
# Finished in 2.4236016273498535 (s)
# ------------------------------
# Iteration (train phase) 207/300
# Finished in 2.450629711151123 (s)
# ------------------------------
# Iteration (train phase) 208/300
# Finished in 2.504877805709839 (s)
# ------------------------------
# Iteration (train phase) 209/300
# Finished in 2.598428726196289 (s)
# ------------------------------
# Iteration (train phase) 210/300
# Finished in 2.445808172225952 (s)
# ------------------------------
# Iteration (train phase) 211/300
# Finished in 2.5260634422302246 (s)
# ------------------------------
# Iteration (train phase) 212/300
# Finished in 2.537437915802002 (s)
# ------------------------------
# Iteration (train phase) 213/300
# Finished in 2.5224664211273193 (s)
# ------------------------------
# Iteration (train phase) 214/300
# Finished in 2.558213233947754 (s)
# ------------------------------
# Iteration (train phase) 215/300
# Finished in 2.631967306137085 (s)
# ------------------------------
# Iteration (train phase) 216/300
# Finished in 2.5257253646850586 (s)
# ------------------------------
# Iteration (train phase) 217/300
# Finished in 2.498270034790039 (s)
# ------------------------------
# Iteration (train phase) 218/300
# Finished in 2.75927472114563 (s)
# ------------------------------
# Iteration (train phase) 219/300
# Finished in 2.500176191329956 (s)
# ------------------------------
# Iteration (train phase) 220/300
# Finished in 2.4745800495147705 (s)
# ------------------------------
# Iteration (train phase) 221/300
# Finished in 2.466921091079712 (s)
# ------------------------------
# Iteration (train phase) 222/300
# Finished in 2.640902519226074 (s)
# ------------------------------
# Iteration (train phase) 223/300
# Finished in 2.4208078384399414 (s)
# ------------------------------
# Iteration (train phase) 224/300
# Finished in 2.481149673461914 (s)
# ------------------------------
# Iteration (train phase) 225/300
# Finished in 2.757395029067993 (s)
# ------------------------------
# Iteration (train phase) 226/300
# Finished in 2.4941859245300293 (s)
# ------------------------------
# Iteration (train phase) 227/300
# Finished in 3.542304277420044 (s)
# ------------------------------
# Iteration (train phase) 228/300
# Finished in 4.193809986114502 (s)
# ------------------------------
# Iteration (train phase) 229/300
# Finished in 1.945237159729004 (s)
# ------------------------------
# Iteration (train phase) 230/300
# Finished in 1.7182624340057373 (s)
# ------------------------------
# Iteration (train phase) 231/300
# Finished in 1.738063097000122 (s)
# ------------------------------
# Iteration (train phase) 232/300
# Finished in 1.7505297660827637 (s)
# ------------------------------
# Iteration (train phase) 233/300
# Finished in 1.7113008499145508 (s)
# ------------------------------
# Iteration (train phase) 234/300
# Finished in 1.6478469371795654 (s)
# ------------------------------
# Iteration (train phase) 235/300
# Finished in 1.6936664581298828 (s)
# ------------------------------
# Iteration (train phase) 236/300
# Finished in 1.6291205883026123 (s)
# ------------------------------
# Iteration (train phase) 237/300
# Finished in 2.493227958679199 (s)
# ------------------------------
# Iteration (train phase) 238/300
# Finished in 2.4836087226867676 (s)
# ------------------------------
# Iteration (train phase) 239/300
# Finished in 2.6150996685028076 (s)
# ------------------------------
# Iteration (train phase) 240/300
# Finished in 2.5128297805786133 (s)
# ------------------------------
# Iteration (train phase) 241/300
# Finished in 2.5063440799713135 (s)
# ------------------------------
# Iteration (train phase) 242/300
# Finished in 2.404179334640503 (s)
# ------------------------------
# Iteration (train phase) 243/300
# Finished in 2.4961531162261963 (s)
# ------------------------------
# Iteration (train phase) 244/300
# Finished in 2.497051239013672 (s)
# ------------------------------
# Iteration (train phase) 245/300
# Finished in 2.4482507705688477 (s)
# ------------------------------
# Iteration (train phase) 246/300
# Finished in 2.5066263675689697 (s)
# ------------------------------
# Iteration (train phase) 247/300
# Finished in 2.7133100032806396 (s)
# ------------------------------
# Iteration (train phase) 248/300
# Finished in 2.55964994430542 (s)
# ------------------------------
# Iteration (train phase) 249/300
# Finished in 2.6212246417999268 (s)
# ------------------------------
# Iteration (train phase) 250/300
# Finished in 2.492734432220459 (s)
# ------------------------------
# Iteration (train phase) 251/300
# Finished in 2.474769353866577 (s)
# ------------------------------
# Iteration (train phase) 252/300
# Finished in 2.596798896789551 (s)
# ------------------------------
# Iteration (train phase) 253/300
# Finished in 2.6391708850860596 (s)
# ------------------------------
# Iteration (train phase) 254/300
# Finished in 2.4899120330810547 (s)
# ------------------------------
# Iteration (train phase) 255/300
# Finished in 2.5588607788085938 (s)
# ------------------------------
# Iteration (train phase) 256/300
# Finished in 2.469099998474121 (s)
# ------------------------------
# Iteration (train phase) 257/300
# Finished in 2.337433099746704 (s)
# ------------------------------
# Iteration (train phase) 258/300
# Finished in 2.508218765258789 (s)
# ------------------------------
# Iteration (train phase) 259/300
# Finished in 2.4708597660064697 (s)
# ------------------------------
# Iteration (train phase) 260/300
# Finished in 2.5507092475891113 (s)
# ------------------------------
# Iteration (train phase) 261/300
# Finished in 2.4462392330169678 (s)
# ------------------------------
# Iteration (train phase) 262/300
# Finished in 2.545097827911377 (s)
# ------------------------------
# Iteration (train phase) 263/300
# Finished in 2.404778480529785 (s)
# ------------------------------
# Iteration (train phase) 264/300
# Finished in 2.455948829650879 (s)
# ------------------------------
# Iteration (train phase) 265/300
# Finished in 2.5460286140441895 (s)
# ------------------------------
# Iteration (train phase) 266/300
# Finished in 2.594428300857544 (s)
# ------------------------------
# Iteration (train phase) 267/300
# Finished in 2.7879903316497803 (s)
# ------------------------------
# Iteration (train phase) 268/300
# Finished in 2.821739673614502 (s)
# ------------------------------
# Iteration (train phase) 269/300
# Finished in 2.743001937866211 (s)
# ------------------------------
# Iteration (train phase) 270/300
# Finished in 2.941965341567993 (s)
# ------------------------------
# Iteration (train phase) 271/300
# Finished in 2.696610689163208 (s)
# ------------------------------
# Iteration (train phase) 272/300
# Finished in 2.76153564453125 (s)
# ------------------------------
# Iteration (train phase) 273/300
# Finished in 2.4749844074249268 (s)
# ------------------------------
# Iteration (train phase) 274/300
# Finished in 2.602179765701294 (s)
# ------------------------------
# Iteration (train phase) 275/300
# Finished in 2.6061949729919434 (s)
# ------------------------------
# Iteration (train phase) 276/300
# Finished in 2.652045488357544 (s)
# ------------------------------
# Iteration (train phase) 277/300
# Finished in 2.5041494369506836 (s)
# ------------------------------
# Iteration (train phase) 278/300
# Finished in 2.5709569454193115 (s)
# ------------------------------
# Iteration (train phase) 279/300
# Finished in 2.665177345275879 (s)
# ------------------------------
# Iteration (train phase) 280/300
# Finished in 2.3121378421783447 (s)
# ------------------------------
# Iteration (train phase) 281/300
# Finished in 2.186462640762329 (s)
# ------------------------------
# Iteration (train phase) 282/300
# Finished in 2.68383526802063 (s)
# ------------------------------
# Iteration (train phase) 283/300
# Finished in 2.6242785453796387 (s)
# ------------------------------
# Iteration (train phase) 284/300
# Finished in 3.1570513248443604 (s)
# ------------------------------
# Iteration (train phase) 285/300
# Finished in 1.6795620918273926 (s)
# ------------------------------
# Iteration (train phase) 286/300
# Finished in 1.7069687843322754 (s)
# ------------------------------
# Iteration (train phase) 287/300
# Finished in 1.7078349590301514 (s)
# ------------------------------
# Iteration (train phase) 288/300
# Finished in 1.815758466720581 (s)
# ------------------------------
# Iteration (train phase) 289/300
# Finished in 1.7543325424194336 (s)
# ------------------------------
# Iteration (train phase) 290/300
# Finished in 1.6898856163024902 (s)
# ------------------------------
# Iteration (train phase) 291/300
# Finished in 1.6963753700256348 (s)
# ------------------------------
# Iteration (train phase) 292/300
# Finished in 1.7363286018371582 (s)
# ------------------------------
# Iteration (train phase) 293/300
# Finished in 1.728365182876587 (s)
# ------------------------------
# Iteration (train phase) 294/300
# Finished in 1.699171781539917 (s)
# ------------------------------
# Iteration (train phase) 295/300
# Finished in 1.6619045734405518 (s)
# ------------------------------
# Iteration (train phase) 296/300
# Finished in 1.772369146347046 (s)
# ------------------------------
# Iteration (train phase) 297/300
# Finished in 1.786470651626587 (s)
# ------------------------------
# Iteration (train phase) 298/300
# Finished in 1.766524076461792 (s)
# ------------------------------
# Iteration (train phase) 299/300
# Finished in 1.733961820602417 (s)
# ------------------------------
# Iteration (train phase) 300/300
# Finished in 1.8030126094818115 (s)
# ------------------------------
# Iteration (validation phase) 1/100
# Finished in 1.714625358581543 (s)
# ------------------------------
# Iteration (validation phase) 2/100
# Finished in 1.7422401905059814 (s)
# ------------------------------
# Iteration (validation phase) 3/100
# Finished in 1.6814157962799072 (s)
# ------------------------------
# Iteration (validation phase) 4/100
# Finished in 1.7273750305175781 (s)
# ------------------------------
# Iteration (validation phase) 5/100
# Finished in 1.628190279006958 (s)
# ------------------------------
# Iteration (validation phase) 6/100
# Finished in 1.6178710460662842 (s)
# ------------------------------
# Iteration (validation phase) 7/100
# Finished in 1.609161138534546 (s)
# ------------------------------
# Iteration (validation phase) 8/100
# Finished in 1.6495342254638672 (s)
# ------------------------------
# Iteration (validation phase) 9/100
# Finished in 1.6723458766937256 (s)
# ------------------------------
# Iteration (validation phase) 10/100
# Finished in 1.656240701675415 (s)
# ------------------------------
# Iteration (validation phase) 11/100
# Finished in 1.6445684432983398 (s)
# ------------------------------
# Iteration (validation phase) 12/100
# Finished in 1.6466128826141357 (s)
# ------------------------------
# Iteration (validation phase) 13/100
# Finished in 1.6339008808135986 (s)
# ------------------------------
# Iteration (validation phase) 14/100
# Finished in 1.6521925926208496 (s)
# ------------------------------
# Iteration (validation phase) 15/100
# Finished in 1.5875585079193115 (s)
# ------------------------------
# Iteration (validation phase) 16/100
# Finished in 1.6079883575439453 (s)
# ------------------------------
# Iteration (validation phase) 17/100
# Finished in 1.6151432991027832 (s)
# ------------------------------
# Iteration (validation phase) 18/100
# Finished in 1.6893019676208496 (s)
# ------------------------------
# Iteration (validation phase) 19/100
# Finished in 1.8771281242370605 (s)
# ------------------------------
# Iteration (validation phase) 20/100
# Finished in 1.7230556011199951 (s)
# ------------------------------
# Iteration (validation phase) 21/100
# Finished in 1.7153043746948242 (s)
# ------------------------------
# Iteration (validation phase) 22/100
# Finished in 1.6163280010223389 (s)
# ------------------------------
# Iteration (validation phase) 23/100
# Finished in 1.7516887187957764 (s)
# ------------------------------
# Iteration (validation phase) 24/100
# Finished in 1.592430591583252 (s)
# ------------------------------
# Iteration (validation phase) 25/100
# Finished in 1.665503978729248 (s)
# ------------------------------
# Iteration (validation phase) 26/100
# Finished in 1.728576421737671 (s)
# ------------------------------
# Iteration (validation phase) 27/100
# Finished in 1.559504508972168 (s)
# ------------------------------
# Iteration (validation phase) 28/100
# Finished in 1.6306183338165283 (s)
# ------------------------------
# Iteration (validation phase) 29/100
# Finished in 1.639159917831421 (s)
# ------------------------------
# Iteration (validation phase) 30/100
# Finished in 1.776585340499878 (s)
# ------------------------------
# Iteration (validation phase) 31/100
# Finished in 1.6383357048034668 (s)
# ------------------------------
# Iteration (validation phase) 32/100
# Finished in 1.8010315895080566 (s)
# ------------------------------
# Iteration (validation phase) 33/100
# Finished in 1.6939525604248047 (s)
# ------------------------------
# Iteration (validation phase) 34/100
# Finished in 1.9346458911895752 (s)
# ------------------------------
# Iteration (validation phase) 35/100
# Finished in 1.6944444179534912 (s)
# ------------------------------
# Iteration (validation phase) 36/100
# Finished in 1.644127607345581 (s)
# ------------------------------
# Iteration (validation phase) 37/100
# Finished in 1.6838994026184082 (s)
# ------------------------------
# Iteration (validation phase) 38/100
# Finished in 1.6951520442962646 (s)
# ------------------------------
# Iteration (validation phase) 39/100
# Finished in 1.6460771560668945 (s)
# ------------------------------
# Iteration (validation phase) 40/100
# Finished in 1.747859001159668 (s)
# ------------------------------
# Iteration (validation phase) 41/100
# Finished in 1.6157441139221191 (s)
# ------------------------------
# Iteration (validation phase) 42/100
# Finished in 1.662048578262329 (s)
# ------------------------------
# Iteration (validation phase) 43/100
# Finished in 1.7412965297698975 (s)
# ------------------------------
# Iteration (validation phase) 44/100
# Finished in 1.6873283386230469 (s)
# ------------------------------
# Iteration (validation phase) 45/100
# Finished in 1.6129448413848877 (s)
# ------------------------------
# Iteration (validation phase) 46/100
# Finished in 1.3747010231018066 (s)
# ------------------------------
# Iteration (validation phase) 47/100
# Finished in 1.3271162509918213 (s)
# ------------------------------
# Iteration (validation phase) 48/100
# Finished in 1.3872215747833252 (s)
# ------------------------------
# Iteration (validation phase) 49/100
# Finished in 1.3191871643066406 (s)
# ------------------------------
# Iteration (validation phase) 50/100
# Finished in 1.3184688091278076 (s)
# ------------------------------
# Iteration (validation phase) 51/100
# Finished in 1.3430638313293457 (s)
# ------------------------------
# Iteration (validation phase) 52/100
# Finished in 1.2837200164794922 (s)
# ------------------------------
# Iteration (validation phase) 53/100
# Finished in 1.3440954685211182 (s)
# ------------------------------
# Iteration (validation phase) 54/100
# Finished in 1.3753008842468262 (s)
# ------------------------------
# Iteration (validation phase) 55/100
# Finished in 1.3255486488342285 (s)
# ------------------------------
# Iteration (validation phase) 56/100
# Finished in 1.4218127727508545 (s)
# ------------------------------
# Iteration (validation phase) 57/100
# Finished in 1.4462590217590332 (s)
# ------------------------------
# Iteration (validation phase) 58/100
# Finished in 1.4039280414581299 (s)
# ------------------------------
# Iteration (validation phase) 59/100
# Finished in 1.3327972888946533 (s)
# ------------------------------
# Iteration (validation phase) 60/100
# Finished in 1.3350701332092285 (s)
# ------------------------------
# Iteration (validation phase) 61/100
# Finished in 1.3123142719268799 (s)
# ------------------------------
# Iteration (validation phase) 62/100
# Finished in 1.3587090969085693 (s)
# ------------------------------
# Iteration (validation phase) 63/100
# Finished in 2.357990264892578 (s)
# ------------------------------
# Iteration (validation phase) 64/100
# Finished in 2.273103952407837 (s)
# ------------------------------
# Iteration (validation phase) 65/100
# Finished in 1.9213378429412842 (s)
# ------------------------------
# Iteration (validation phase) 66/100
# Finished in 2.2143537998199463 (s)
# ------------------------------
# Iteration (validation phase) 67/100
# Finished in 2.1751153469085693 (s)
# ------------------------------
# Iteration (validation phase) 68/100
# Finished in 2.228145122528076 (s)
# ------------------------------
# Iteration (validation phase) 69/100
# Finished in 1.8097498416900635 (s)
# ------------------------------
# Iteration (validation phase) 70/100
# Finished in 2.0680906772613525 (s)
# ------------------------------
# Iteration (validation phase) 71/100
# Finished in 2.717466115951538 (s)
# ------------------------------
# Iteration (validation phase) 72/100
# Finished in 2.1346516609191895 (s)
# ------------------------------
# Iteration (validation phase) 73/100
# Finished in 2.5668890476226807 (s)
# ------------------------------
# Iteration (validation phase) 74/100
# Finished in 3.0753514766693115 (s)
# ------------------------------
# Iteration (validation phase) 75/100
# Finished in 2.615114688873291 (s)
# ------------------------------
# Iteration (validation phase) 76/100
# Finished in 2.188215970993042 (s)
# ------------------------------
# Iteration (validation phase) 77/100
# Finished in 2.4543731212615967 (s)
# ------------------------------
# Iteration (validation phase) 78/100
# Finished in 2.373387575149536 (s)
# ------------------------------
# Iteration (validation phase) 79/100
# Finished in 2.1593024730682373 (s)
# ------------------------------
# Iteration (validation phase) 80/100
# Finished in 2.98909330368042 (s)
# ------------------------------
# Iteration (validation phase) 81/100
# Finished in 3.026379346847534 (s)
# ------------------------------
# Iteration (validation phase) 82/100
# Finished in 2.9177157878875732 (s)
# ------------------------------
# Iteration (validation phase) 83/100
# Finished in 2.588909864425659 (s)
# ------------------------------
# Iteration (validation phase) 84/100
# Finished in 2.6535589694976807 (s)
# ------------------------------
# Iteration (validation phase) 85/100
# Finished in 2.3719518184661865 (s)
# ------------------------------
# Iteration (validation phase) 86/100
# Finished in 2.2096545696258545 (s)
# ------------------------------
# Iteration (validation phase) 87/100
# Finished in 3.255753755569458 (s)
# ------------------------------
# Iteration (validation phase) 88/100
# Finished in 2.4434564113616943 (s)
# ------------------------------
# Iteration (validation phase) 89/100
# Finished in 2.7620503902435303 (s)
# ------------------------------
# Iteration (validation phase) 90/100
# Finished in 2.501643419265747 (s)
# ------------------------------
# Iteration (validation phase) 91/100
# Finished in 1.5323843955993652 (s)
# ------------------------------
# Iteration (validation phase) 92/100
# Finished in 1.6369578838348389 (s)
# ------------------------------
# Iteration (validation phase) 93/100
# Finished in 1.6213812828063965 (s)
# ------------------------------
# Iteration (validation phase) 94/100
# Finished in 1.6248021125793457 (s)
# ------------------------------
# Iteration (validation phase) 95/100
# Finished in 1.5721194744110107 (s)
# ------------------------------
# Iteration (validation phase) 96/100
# Finished in 1.620898723602295 (s)
# ------------------------------
# Iteration (validation phase) 97/100
# Finished in 1.8691935539245605 (s)
# ------------------------------
# Iteration (validation phase) 98/100
# Finished in 1.8943040370941162 (s)
# ------------------------------
# Iteration (validation phase) 99/100
# Finished in 2.509901762008667 (s)
# ------------------------------
# Iteration (validation phase) 100/100
# Finished in 2.3585264682769775 (s)
# Epoch 1 - accuracy: 0.994
# ------------------------------------------------------------------------
# Finished epoch 1 in 1225.6522839069366 (s).

# %% [markdown]
# <b>Print out the Accuracy and plot the loss stored in the list <code>loss_list</code> for every iteration and take a screen shot.</b>

# %%
accuracy
# Out:
# 0.9943

# %%
plt.plot(loss_list)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# ## Question 3:Find the misclassified samples

# %% [markdown]
# <b>Identify the first four misclassified samples using the validation data:</b>

# %%
validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=1)
count = 0

for index, (x, y) in enumerate(validation_loader):
    model.eval()
    z = model(x)
    _,yhat = torch.max(z.data, 1)
    if not torch.all(yhat.eq(y)):
        count += 1
        print(f"sample {index} predicted value: {yhat} actual value:{y}")
        if count == 4:
            break
# Out:
# sample 22 predicted value: tensor([0]) actual value:tensor([1])
# sample 101 predicted value: tensor([1]) actual value:tensor([0])
# sample 182 predicted value: tensor([0]) actual value:tensor([1])
# sample 213 predicted value: tensor([1]) actual value:tensor([0])

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/share-notebooks.html"> CLICK HERE </a> Click here to see how to share your notebook.

# %% [markdown]
# ## About the Authors
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Copyright &copy; 2018 <a href="cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu">cognitiveclass.ai</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/">MIT License</a>.
